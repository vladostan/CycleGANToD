# %%
import visdom
import numpy as np
vis = visdom.Visdom()
vis.text('Hello, world!')
vis.image(np.ones((3, 10, 10)))
# Out:
# WARNING:root:Setting up a new session...
# Traceback (most recent call last):
#   File "/home/kenny/.local/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/kenny/.local/lib/python3.6/site-packages/urllib3/util/connection.py", line 83, in create_connection
#     raise err
#   File "/home/kenny/.local/lib/python3.6/site-packages/urllib3/util/connection.py", line 73, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/kenny/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/kenny/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 357, in _make_request
#     conn.request(method, url, **httplib_request_kw)
# ...

# %%
vis = require 'visdom'()
vis.ipv6 = false  -- switches off IPv6
vis:text{text = 'Hello, world!'}реква
# Out:
#   File "<ipython-input-3-784ec5703f72>", line 1
#     vis = require 'visdom'()
#                          ^
# SyntaxError: invalid syntax
